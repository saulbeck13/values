# %%
import networkx as nx
import pylab as plt
from networkx.drawing.nx_agraph import graphviz_layout, to_agraph

# %%
values = nx.DiGraph()

values.add_node("Values")

#Highest level topics 
values.add_node("Self-Trancendence")
values.add_node("Conservation")
values.add_node("Openness to change")
values.add_node("Self-enhancement")

#Subtopics
values.add_node("Self-Direction")
values.add_node("Stimulation")
values.add_node("Hedonism")
values.add_node("Achievement")
values.add_node("Power")
values.add_node("Face")
values.add_node("Security")
values.add_node("Conformity")
values.add_node("Tradition")
values.add_node("Humility")
values.add_node("Benevolence")
values.add_node("Universalism")

#Sub-subtopics
#Self Direction
values.add_node("Self-Direction Thought")
values.add_node("Self-Direction Action")
#Power
values.add_node("Power Dominance")
values.add_node("Power Resources")
#Security
values.add_node("Security Personal")
values.add_node("Security Societal")
#Conformity
values.add_node("Conformity Rules")
values.add_node("Conformity Interpersonal")
#Benevolence
values.add_node("Benevolence Dependability")
values.add_node("Benevolence Caring")
#Universalism
values.add_node("Universalism Nature")
values.add_node("Universalism Tolerance")
values.add_node("Universalism Concern")



#Openness to change sub sub topics
values.add_node("Privacy")
values.add_node("Curious")
values.add_node("Freedom")
values.add_node("Independent")
values.add_node("Creativity")
values.add_node("Excitement in life")
values.add_node("Daring")
values.add_node("Enjoying life")
values.add_node("Pleasure") #Also in self-enhancement

#Self-enhancement sub sub 
values.add_node("Pleasure") #Also in openness to change
values.add_node("Ambitious")
values.add_node("Influential")
values.add_node("Authority")
values.add_node("Social power")
values.add_node("Wealth")
values.add_node("Social recognition")
values.add_node("Preserving public image")

#Conservation sub sub
values.add_node("Clean")
values.add_node("Healthy")
values.add_node("Family security")
values.add_node("National security")
values.add_node("Belonging")
values.add_node("Social order")
values.add_node("Respect for tradition")
values.add_node("Devout")
values.add_node("Obedient")
values.add_node("Politeness")
values.add_node("Honoring elders")
values.add_node("Humble")
values.add_node("Accepting my portion in life") #Also in self-transcendence

#Self Transcendence sub sub
values.add_node("Accepting my portion in life") #Also in conservation
values.add_node("Helpful")
values.add_node("Forgiving")
values.add_node("Loyal")
values.add_node("True friendship")
values.add_node("Social justice")
values.add_node("Equality")
values.add_node("Protecting the environment")
values.add_node("Unity with nature")
values.add_node("Broad minded")
values.add_node("A world at peace")



values.add_edge("Values", "Self-Trancendence")
values.add_edge("Values", "Conservation")
values.add_edge("Values", "Openness to change")
values.add_edge("Values", "Self-enhancement")


values.add_edge("Openness to change", "Self-Direction")
values.add_edge("Self-Direction", "Self-Direction Thought")
values.add_edge("Self-Direction", "Self-Direction Action")

values.add_edge("Openness to change", "Stimulation")
values.add_edge("Openness to change", "Hedonism")

values.add_edge("Self-enhancement", "Hedonism")
values.add_edge("Self-enhancement", "Achievement")
values.add_edge("Self-enhancement", "Power")
values.add_edge("Power", "Power Dominance")
values.add_edge("Power", "Power Resources")
values.add_edge("Self-enhancement", "Face")


values.add_edge("Conservation", "Face")
values.add_edge("Conservation", "Security")
values.add_edge("Security", "Security Personal")
values.add_edge("Security", "Security Societal")
values.add_edge("Conservation", "Tradition")
values.add_edge("Conservation", "Conformity")
values.add_edge("Conformity", "Conformity Rules")
values.add_edge("Conformity", "Conformity Interpersonal")
values.add_edge("Conservation", "Humility")

values.add_edge("Self-Trancendence", "Humility")
values.add_edge("Self-Trancendence", "Benevolence")
values.add_edge("Benevolence", "Benevolence Dependability")
values.add_edge("Benevolence", "Benevolence Caring")
values.add_edge("Self-Trancendence", "Universalism")
values.add_edge("Universalism", "Universalism Nature")
values.add_edge("Universalism", "Universalism Tolerance")
values.add_edge("Universalism", "Universalism Concern")





values.add_edge("Self-Direction", "Privacy")
values.add_edge("Self-Direction", "Curious")
values.add_edge("Self-Direction", "Freedom")
values.add_edge("Self-Direction", "Independent")
values.add_edge("Self-Direction", "Creativity")
values.add_edge("Stimulation", "Excitement in life")
values.add_edge("Stimulation", "Daring")
values.add_edge("Stimulation", "Enjoying life")
values.add_edge("Hedonism", "Pleasure")
values.add_edge("Hedonism", "Pleasure")
values.add_edge("Achievement", "Ambitious")
values.add_edge("Achievement", "Successful")
values.add_edge("Achievement", "Influential")
values.add_edge("Power", "Authority")
values.add_edge("Power", "Social power")
values.add_edge("Power", "Wealth")
values.add_edge("Power", "Social recognition")
values.add_edge("Power", "Preserving public image")
values.add_edge("Face", "Preserving public image")
values.add_edge("Security", "Clean")
values.add_edge("Security", "Healthy")
values.add_edge("Security", "Family security")
values.add_edge("Security", "National security")
values.add_edge("Security", "Belonging")
values.add_edge("Security", "Social order")
values.add_edge("Tradition", "Respect for tradition")
values.add_edge("Tradition", "Devout")
values.add_edge("Conformity", "Obedient")
values.add_edge("Conformity", "Politeness")
values.add_edge("Conformity", "Honoring elders")
values.add_edge("Humility", "Humble")
values.add_edge("Humility", "Accepting my portion in life")


values.add_edge("Benevolence", "Helpful")
values.add_edge("Benevolence", "Forgiving")
values.add_edge("Benevolence", "Loyal")
values.add_edge("Benevolence", "True friendship")
values.add_edge("Universalism", "Social justice")
values.add_edge("Universalism", "Equality")
values.add_edge("Universalism", "Protecting the environment")
values.add_edge("Universalism", "Unity with nature")
values.add_edge("Universalism", "Broad minded")
values.add_edge("Universalism", "A world at peace")

# %%
nx.write_gexf(values, "some_graph.gexf")

# %%
import plotly.express as px 
import pandas as pd
df1 = pd.read_excel('values.xlsx')  
df = px.data.gapminder().query("year == 2007")


df1.head()
# Out:
#     Value                Top        Middle            Low  Unnamed: 4  Score
# 0  Values  Self Trancendence      Humility            NaN         NaN     10
# 1  Values  Self Trancendence   Benevolence         Caring         NaN      9
# 2  Values  Self Trancendence   Benevolence  Dependability         NaN     10
# 3  Values  Self Trancendence  Universalism        Concern         NaN      2
# 4  Values  Self Trancendence  Universalism         Nature         NaN     15

# %%
import plotly.express as px
import numpy as np
df = px.data.gapminder().query("year == 2007")
fig = px.sunburst(df1, path=['Value','Top', 'Middle', 'Low', 'Bottom'], values='Score')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 4
#       2 import numpy as np
#       3 df = px.data.gapminder().query("year == 2007")
# ----> 4 fig = px.sunburst(df1, path=['Value','Top', 'Middle', 'Low', 'Bottom'], values='Score')
#       5 fig.show()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\plotly\express\_chart_types.py:1541, in sunburst(data_frame, names, values, parents, path, ids, color, color_continuous_scale, range_color, color_continuous_midpoint, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, branchvalues, maxdepth)
#    1539 if path is not None and branchvalues is None:
#    1540     branchvalues = "total"
# -> 1541 return make_figure(
#    1542     args=locals(),
#    1543     constructor=go.Sunburst,
# ...
